# %%
import pprint
import googlemaps

# %%
API_KEY = ''

# %%
gmaps = googlemaps.Client(key=API_KEY)

# %%
places_result  = gmaps.places_nearby(location='-33.8670522,151.1957362', radius = 40000, open_now =False , type = 'restaurant')

# %%
pprint.pprint(places_result)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATJ83zioOKwMN_37jrVjHOAjXdd1la9AqgJvrQWPM1nXGTzLVfBzlekif0ncdleqJ-3XLMGCeLJmZ5O0dvgGo3l3x8cI-idPctSWMLg1eECNk7B9kf7kXArWcYWyDqZEGH7cnJjjMoa3GRCwSBCamPlfNJSzUR3sW7RAi5mmCo0o3kGqSByjOgDBdekH00U7er-DSpUUs8CkxK8XJQ39m7YXnsyAD3Auki7XhU5-L8YpE6NgLUwRFoCjX1WT0ba_sXjemvp4yRYXjui01pl34ckjazlXBODp5GTG0otRPN2OmZt-MM8YnHoRf6UpTFkg8_hT9-OaEJodScGbyjlGh1u_hyHBIO1FEACVmg-0JsQHUeLQoK9Zyb_wxVtC4Y0gGzDKNymAj1kQ6ZKPioR3Mm0mqEAiIru77laUYveKTzOT7ZrIv2078k_MS0fquXxB',
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.864458, 'lng': 151.2062952},
#                            'viewport': {'northeast': {'lat': -33.8630026197085,
#                                                       'lng': 151.2075776802915},
#                                         'southwest': {'lat': -33.8657005802915,
#                                                       'lng': 151.2048797197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Amora Hotel Jamison Sydney',
#               'photos': [{'height': 4088,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112581335421444049471">Amora '
#                                                 'Hotel Jamison Sydney</a>'],
#                           'photo_reference': 'ATJ83zhvcMjGzeYbIVXU-gWVjTOndxbTr62mbx2-jMnqsrW3GDYx04YFSo5RVcQ6dmcQrMztngQiqCu4miQ-8Js68dQynuWk5cSz4n82gSPr1Dh6GbNDIssyo5DXrOLs96HH16ap-7ptriaTPJZCSEELroNBvjXCzwRCOdb8slTdqnS5OlW8',
#                           'width': 3066}],
#               'place_id': 'ChIJa51FEUGuEmsRIXRtDjLFQXM',
#               'plus_code': {'compound_code': '46P4+6G Sydney NSW, Australia',
#                             'global_code': '4RRH46P4+6G'},
#               'price_level': 3,
#               'rating': 4.2,
#               'reference': 'ChIJa51FEUGuEmsRIXRtDjLFQXM',
#               'scope': 'GOOGLE',
#               'types': ['spa',
#                         'bar',
#                         'restaurant',
#                         'lodging',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 2280,
#               'vicinity': '11 Jamison Street, Sydney'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.870383, 'lng': 151.1979245},
#                            'viewport': {'northeast': {'lat': -33.86901176970849,
#                                                       'lng': 151.1991694302915},
#                                         'southwest': {'lat': -33.87170973029149,
#                                                       'lng': 151.1964714697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'The Little Snail Restaurant',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 900,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114727320476039103791">The '
#                                                 'Little Snail Restaurant</a>'],
#                           'photo_reference': 'ATJ83zg-67Ys2HflGJdMLPEmOIbBcapczs22OOktvFkd2_UX7oFVEuMe28IYrF6gFCNcsXtuwUSbcE3A0m8H-HI58azpQlQy6uP1deG_VSw8CWNp4TIjJR5NlgxLcCUlAfGMPFLoySo_SlH6HjX44DJbZuhctpFimM1irBlSgFnoMpvKLUQ-',
#                           'width': 1350}],
#               'place_id': 'ChIJtwapWjeuEmsRcxV5JARHpSk',
#               'plus_code': {'compound_code': '45HX+R5 Pyrmont NSW, Australia',
#                             'global_code': '4RRH45HX+R5'},
#               'price_level': 2,
#               'rating': 4.5,
#               'reference': 'ChIJtwapWjeuEmsRcxV5JARHpSk',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 2376,
#               'vicinity': '3/50 Murray Street, Pyrmont'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.8709065, 'lng': 151.2075485},
#                            'viewport': {'northeast': {'lat': -33.86945936970849,
#                                                       'lng': 151.2088507802915},
#                                         'southwest': {'lat': -33.87215733029149,
#                                                       'lng': 151.2061528197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'QT Sydney',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2303,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117184769815937888065">QT '
#                                                 'Sydney</a>'],
#                           'photo_reference': 'ATJ83zjxU32otnOdDwS69Fz7abRFKSCKWrvfVk3RIfYS94iIsIxs8gGxl8krKIEvvZIfVWYMcCF14NTOlpXZscHPX9sUawXlBrzkc0kNm065YEcwD8hr0GlGSu6G-helu2YDnsp7QQDdAAMpzAFZqJpJ21BXgYdUkYmrm7F2do101NVOi16r',
#                           'width': 2303}],
#               'place_id': 'ChIJK6RwVT6uEmsRQ447JSUTGGI',
#               'plus_code': {'compound_code': '46H5+J2 Sydney NSW, Australia',
#                             'global_code': '4RRH46H5+J2'},
#               'rating': 4.6,
#               'reference': 'ChIJK6RwVT6uEmsRQ447JSUTGGI',
#               'scope': 'GOOGLE',
#               'types': ['bar',
#                         'restaurant',
#                         'lodging',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1824,
#               'vicinity': '49 Market Street, Sydney'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.87222569999999,
#                                         'lng': 151.2020367},
#                            'viewport': {'northeast': {'lat': -33.87090036970851,
#                                                       'lng': 151.2034596302915},
#                                         'southwest': {'lat': -33.8735983302915,
#                                                       'lng': 151.2007616697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': "Nick's Seafood Restaurant",
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 506,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104361025827203327119">Nick&#39;s '
#                                                 'Seafood Restaurant</a>'],
#                           'photo_reference': 'ATJ83ziuY3hySmGmZdYwuy0fZ9-aIhnw779t26CAOt5zQa4f-OgaxFPFcqpwMqbdfAqvYrf76A2qtuPh70FgWG-HnrfQmm4CS_1FfZkgOQKwIawFeahrn4M7YZUn3VrTcP18KqglDLtZcgvj8dPfF6dseoyOhCo5kF8ZVoMUEe_t1JFmCV8b',
#                           'width': 759}],
#               'place_id': 'ChIJvwSIiTiuEmsRAjBcCjGBYsw',
#               'plus_code': {'compound_code': '46H2+4R Sydney NSW, Australia',
#                             'global_code': '4RRH46H2+4R'},
#               'price_level': 3,
#               'rating': 4,
#               'reference': 'ChIJvwSIiTiuEmsRAjBcCjGBYsw',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 2743,
#               'vicinity': 'The Promenade, Cockle Bay Wharf, Darling Harbour, '
#                           'Sydney'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.8666848, 'lng': 151.2015819},
#                            'viewport': {'northeast': {'lat': -33.86532001970851,
#                                                       'lng': 151.2030457302915},
#                                         'southwest': {'lat': -33.8680179802915,
#                                                       'lng': 151.2003477697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Steersons Steakhouse',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1538,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110384774118527817485">Steersons '
#                                                 'Steakhouse</a>'],
#                           'photo_reference': 'ATJ83zhJXzlYz0_2qVUZMl8HttNPVRq6np6AFiBgcYMsjwHdnLCRg2Zn4ezLQpm2e-E1aZmeUP2A_QMpRY15TCs_vv3Z-C6RwO9p74SGgOBhFxYnLTO0NHt6QshnDpHOta2E00p2xI21owEzILCSPuzp4QDumm-M-BAdS--A5vnrjIzddclW',
#                           'width': 2048}],
#               'place_id': 'ChIJWRxefkeuEmsRn2tDqHg6HQo',
#               'plus_code': {'compound_code': '46M2+8J Sydney NSW, Australia',
#                             'global_code': '4RRH46M2+8J'},
#               'price_level': 3,
#               'rating': 4.3,
#               'reference': 'ChIJWRxefkeuEmsRn2tDqHg6HQo',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 800,
#               'vicinity': '17 Lime Street, Sydney'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.8702637, 'lng': 151.2074559},
#                            'viewport': {'northeast': {'lat': -33.8691519197085,
#                                                       'lng': 151.2087574302915},
#                                         'southwest': {'lat': -33.8718498802915,
#                                                       'lng': 151.2060594697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Swissôtel Sydney',
#               'photos': [{'height': 2130,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109617038450514957756">Swissôtel '
#                                                 'Sydney</a>'],
#                           'photo_reference': 'ATJ83zhx8JbNaVLVl_Yb69ou_yoMutkDYLd_vGYD8ryymDjEae-gbj4HSeFp7S6u726YPHjfwX7y6EMFuarhcHbVP1joJvt3D75pTtIknOmF3A0D-YWXofI6ru_YwCaNwNGX9j0JhsR63gI5r6V0DANdJ2hQRvmkHoyq1PpciFzTjNWOnXdy',
#                           'width': 3000}],
#               'place_id': 'ChIJAddzqj-uEmsRO8NmIaLn1t0',
#               'plus_code': {'compound_code': '46H4+VX Sydney NSW, Australia',
#                             'global_code': '4RRH46H4+VX'},
#               'rating': 4.3,
#               'reference': 'ChIJAddzqj-uEmsRO8NmIaLn1t0',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'lodging',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 2304,
#               'vicinity': '68 Market Street, Sydney'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.866664, 'lng': 151.2014112},
#                            'viewport': {'northeast': {'lat': -33.86545711970849,
#                                                       'lng': 151.2029715302915},
#                                         'southwest': {'lat': -33.86815508029149,
#                                                       'lng': 151.2002735697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#               'name': 'Georges Mediterranean Bar & Grill',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 829,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109724308524689410874">Georges '
#                                                 'Mediterranean Bar &amp; '
#                                                 'Grill</a>'],
#                           'photo_reference': 'ATJ83zh7chg87OA6JBIDKmy-sML4T9XZcAhyHX1Uph00Ic5Zz0yJ04QK8ovNcled4rDcRB1so3UJTPm0q-4-hkeNq1Zn0QLjGaJ6NMR94_AJUSBCOlEYULypTY1zGtlOyWAgZ0n8RTt3ppeIZKP8QKa5IdpNdSrmuXKwyU-nw_geIVRqJQvF',
#                           'width': 1244}],
#               'place_id': 'ChIJWRxefkeuEmsRmKvNb_DeLt8',
#               'plus_code': {'compound_code': '46M2+8H Sydney NSW, Australia',
#                             'global_code': '4RRH46M2+8H'},
#               'price_level': 2,
#               'rating': 3.9,
#               'reference': 'ChIJWRxefkeuEmsRmKvNb_DeLt8',
#               'scope': 'GOOGLE',
#               'types': ['bar',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 900,
#               'vicinity': 'King Street Wharf, 3 The Promenade, Sydney'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.8717324, 'lng': 151.2021438},
#                            'viewport': {'northeast': {'lat': -33.87046746970849,
#                                                       'lng': 151.2035867802915},
#                                         'southwest': {'lat': -33.87316543029149,
#                                                       'lng': 151.2008888197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Adria Bar Restaurant',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 506,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100168888649439855862">Adria '
#                                                 'Bar Restaurant</a>'],
#                           'photo_reference': 'ATJ83zha86SwIwJmo9soRAd1aJpDPjx84UFWncM5k4RujPhWkX-4n90g4vPlhVmleebQtfQT-aQy2NikeDR9vNKS9DG8rqlaGr0QR1ui1wRJwI_iXg_hOduLYuCXrjoiuC5EGMpPZc3deOFPoks8O2sD7_0zKrsGqHIx6zBOGSCsYqUJsthK',
#                           'width': 759}],
#               'place_id': 'ChIJ8RXmITmuEmsRznrugcSQwxU',
#               'plus_code': {'compound_code': '46H2+8V Sydney NSW, Australia',
#                             'global_code': '4RRH46H2+8V'},
#               'price_level': 2,
#               'rating': 3.6,
#               'reference': 'ChIJ8RXmITmuEmsRznrugcSQwxU',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'bar',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1586,
#               'vicinity': 'The Promenade, Cockle Bay Wharf Darling Harbour, '
#                           'Wheat Road, Sydney'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.87199679999999,
#                                         'lng': 151.2023264},
#                            'viewport': {'northeast': {'lat': -33.8706661697085,
#                                                       'lng': 151.2037495302915},
#                                         'southwest': {'lat': -33.8733641302915,
#                                                       'lng': 151.2010515697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': "I'm Angus Steakhouse",
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100297166708465188775">大北洋士</a>'],
#                           'photo_reference': 'ATJ83zhUbD8VSOb-kHInwnYTTrPZyP5A_DbobJi1viGmaI73yAYVlSK_wdsidZqeS_k--A7kFu6kHhSIG9jFug5ISlZoqYMF49Nu5k-v1PdvHUyzsPItwDWK78V4BEUfa2lOQGvSeAi_jyw7vuoKgry6X_yqadEfI0Uo-_nu5-wBu8gWvUBX',
#                           'width': 3024}],
#               'place_id': 'ChIJvwSIiTiuEmsRBfZvg037JFM',
#               'plus_code': {'compound_code': '46H2+6W Sydney NSW, Australia',
#                             'global_code': '4RRH46H2+6W'},
#               'price_level': 3,
#               'rating': 3.9,
#               'reference': 'ChIJvwSIiTiuEmsRBfZvg037JFM',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1401,
#               'vicinity': 'The Promenade, Cockle Bay Wharf, Darling Harbour, '
#                           'Sydney'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.8732123, 'lng': 151.2049633},
#                            'viewport': {'northeast': {'lat': -33.8718893197085,
#                                                       'lng': 151.2064088302915},
#                                         'southwest': {'lat': -33.8745872802915,
#                                                       'lng': 151.2037108697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Nomads Sydney',
#               'photos': [{'height': 810,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102842115596557668315">Marina '
#                                                 'Maria</a>'],
#                           'photo_reference': 'ATJ83zg95YBYhqycXDjOWsano9tb1w7Ix1e2X0VhyM-x_ge35rtaawG_t6T2A9Q2a-pHrTMDcSxJLnbOG5NO8ZsAGwA6jVB83E0b-Fsasn4KtxsNd8wHl8D0sHuaTCwuoTBaINebul8dsdp_PAeBqgHmv0Wpw_qwVYfTXz4cG7rp1XhIrBBB',
#                           'width': 1225}],
#               'place_id': 'ChIJKwL_BDyuEmsROVMxBbEOOnk',
#               'plus_code': {'compound_code': '46G3+PX Sydney NSW, Australia',
#                             'global_code': '4RRH46G3+PX'},
#               'rating': 3.9,
#               'reference': 'ChIJKwL_BDyuEmsROVMxBbEOOnk',
#               'scope': 'GOOGLE',
#               'types': ['local_government_office',
#                         'travel_agency',
#                         'bar',
#                         'restaurant',
#                         'lodging',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1110,
#               'vicinity': '477 Kent Street, Sydney'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.8679688, 'lng': 151.2053027},
#                            'viewport': {'northeast': {'lat': -33.8666265197085,
#                                                       'lng': 151.2065754802915},
#                                         'southwest': {'lat': -33.8693244802915,
#                                                       'lng': 151.2038775197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Bistro Papillon',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 856,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113979308042018146627">Bistro '
#                                                 'Papillon</a>'],
#                           'photo_reference': 'ATJ83zh2e8GyfIqawGBsTK3doCSNDdy6bWXrf8rarnd5QhewmH568vXW6j0XVWWZiJB73WX_39S0sWltS5ZtkYSVujnPQzeaGg56ukSBldPYToTdUovUS8vhRriM3K42T7V8-nlA-g6F98SJc5KdIUzUWVzP99KGkZUeQfgz7DbTdpQ4gRgz',
#                           'width': 1300}],
#               'place_id': 'ChIJywXDWT-uEmsRxyuZ0Inwi04',
#               'plus_code': {'compound_code': '46J4+R4 Sydney NSW, Australia',
#                             'global_code': '4RRH46J4+R4'},
#               'price_level': 3,
#               'rating': 4.5,
#               'reference': 'ChIJywXDWT-uEmsRxyuZ0Inwi04',
#               'scope': 'GOOGLE',
#               'types': ['meal_takeaway',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 628,
#               'vicinity': '98 Clarence Street, Sydney'},
#              {'business_status': 'CLOSED_TEMPORARILY',
#               'geometry': {'location': {'lat': -33.8605708, 'lng': 151.2066137},
#                            'viewport': {'northeast': {'lat': -33.8592176197085,
#                                                       'lng': 151.2078904302915},
#                                         'southwest': {'lat': -33.86191558029149,
#                                                       'lng': 151.2051924697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Sydney Harbour Bed & Breakfast',
#               'permanently_closed': True,
#               'photos': [{'height': 4000,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117351006581217688918">John '
#                                                 'karmas</a>'],
#                           'photo_reference': 'ATJ83zhGRDWA2vyApwxjc6yww7sGBDvbMjxRm72nJNTsqYvgsm9ujo5SXcViJi26q2odVHA4a75EhuRmWy1-F6uRuiYKgv_ursUna-IUy9clLSeh8ekkDF7a_suTcSH0bFykgk-17GA14b31BgBl3bIDTFqXr7Fdg66J_18yN7t9XHoEAFDP',
#                           'width': 3000}],
#               'place_id': 'ChIJCfGaqEOuEmsRW8wvWsTgIyE',
#               'plus_code': {'compound_code': '46Q4+QJ The Rocks NSW, Australia',
#                             'global_code': '4RRH46Q4+QJ'},
#               'rating': 4,
#               'reference': 'ChIJCfGaqEOuEmsRW8wvWsTgIyE',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'lodging',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 118,
#               'vicinity': '140-142 Cumberland Street, The Rocks'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.8682602, 'lng': 151.2061468},
#                            'viewport': {'northeast': {'lat': -33.8669133197085,
#                                                       'lng': 151.2074132802915},
#                                         'southwest': {'lat': -33.8696112802915,
#                                                       'lng': 151.2047153197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'The Bavarian York St.',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1163,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101805362363929814662">The '
#                                                 'Bavarian York St.</a>'],
#                           'photo_reference': 'ATJ83zgARM6SYB3xLEUZY6Ha5N7R6UtQq2LpMXa1OIG75yYzyPRDE1ijgV_S5yAqT8uim9EqkTXCSuBTood9IX_JWJj4PDJl_SS-McnAyvMDDq1tB86LL3EmVfAVMllnjDOOJPgGna5LmjaMwxEsnOka1W_ytor8pPB-DVK9CdX3QzZxj_rq',
#                           'width': 2704}],
#               'place_id': 'ChIJ6d4iYT-uEmsRzr2ghGVI_6s',
#               'plus_code': {'compound_code': '46J4+MF Sydney NSW, Australia',
#                             'global_code': '4RRH46J4+MF'},
#               'price_level': 2,
#               'rating': 4.1,
#               'reference': 'ChIJ6d4iYT-uEmsRzr2ghGVI_6s',
#               'scope': 'GOOGLE',
#               'types': ['bar',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 3172,
#               'vicinity': '24 York Street, Sydney'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.8683472, 'lng': 151.1962233},
#                            'viewport': {'northeast': {'lat': -33.8668080197085,
#                                                       'lng': 151.19717155},
#                                         'southwest': {'lat': -33.8695059802915,
#                                                       'lng': 151.19337855}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Flying Fish',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3907,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117229116771790632690">Flying '
#                                                 'Fish</a>'],
#                           'photo_reference': 'ATJ83zhYrgNFtmhQzUn-mijfGWPGHu4OJNVO5G5e6EnVwlLURJ5oS_ipnn96xSrfez66MV5N9w0w0NYhN2k9jmhvFAseflhZUR0jRP6Vne3q9mlrubMlee6pv6zL4HcfS_lxGvjn6mEkteMtkVsw2SYQ_W-x-eGaTapKpNX9EEWG4njBQlw5',
#                           'width': 5373}],
#               'place_id': 'ChIJm7Ex8UmuEmsR37p4Hm0D0VI',
#               'plus_code': {'compound_code': '45JW+MF Pyrmont NSW, Australia',
#                             'global_code': '4RRH45JW+MF'},
#               'price_level': 1,
#               'rating': 4.4,
#               'reference': 'ChIJm7Ex8UmuEmsR37p4Hm0D0VI',
#               'scope': 'GOOGLE',
#               'types': ['bar',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1190,
#               'vicinity': '80 Pyrmont Street, Pyrmont'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.867806, 'lng': 151.2017201},
#                            'viewport': {'northeast': {'lat': -33.8664656697085,
#                                                       'lng': 151.2031799802915},
#                                         'southwest': {'lat': -33.8691636302915,
#                                                       'lng': 151.2004820197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'The Malaya',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 885,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112797482079521405927">The '
#                                                 'Malaya</a>'],
#                           'photo_reference': 'ATJ83zjFtC-8f-DN0947YnA8eu84lq401IquYkNhbNOkIhrg4MAqTXLefybKyPSJ9krfzPC44fNQDIR3uMk7Fh5LTvTqjWFbCXwrLYaABy3sH7t0Y8ejJpB03AjKhG0IlW900rCwG5TQn_q-uKL5HCoyuiMghNnb4mSORGJExjDWSRclDh-r',
#                           'width': 884}],
#               'place_id': 'ChIJ4U8HhjiuEmsRyevJVTxWbFo',
#               'plus_code': {'compound_code': '46J2+VM Sydney NSW, Australia',
#                             'global_code': '4RRH46J2+VM'},
#               'price_level': 3,
#               'rating': 4.5,
#               'reference': 'ChIJ4U8HhjiuEmsRyevJVTxWbFo',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1608,
#               'vicinity': '39 Lime Street, Sydney'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.8652682, 'lng': 151.2071764},
#                            'viewport': {'northeast': {'lat': -33.8640030197085,
#                                                       'lng': 151.2086016302915},
#                                         'southwest': {'lat': -33.8667009802915,
#                                                       'lng': 151.2059036697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Toko Restaurant',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 2634,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115482178127043933395">Toko '
#                                                 'Restaurant</a>'],
#                           'photo_reference': 'ATJ83zgS-T4TiJLkxN48m2LSIWpZEp1GLgH6NuDGEpLJGoa2Xo0yOtFaCKGmeF6jGJADR2Mxy9joAcOGGrqYXtux4dy-5ab50pTJAcO6rrZ_48NRblSbmSE9mFIA0e_x1_eGOTwioH572LuWFVq5VL9_BX2PRvy2o2-RH9af2_kqcKwVrQHS',
#                           'width': 3510}],
#               'place_id': 'ChIJT-EHWQauEmsRZyvdi-Tn1nA',
#               'plus_code': {'compound_code': '46M4+VV Sydney NSW, Australia',
#                             'global_code': '4RRH46M4+VV'},
#               'price_level': 3,
#               'rating': 4.3,
#               'reference': 'ChIJT-EHWQauEmsRZyvdi-Tn1nA',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 981,
#               'vicinity': 'Entry at, Lower Ground, 275 George Street, only'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.8685511, 'lng': 151.2033518},
#                            'viewport': {'northeast': {'lat': -33.86716601970849,
#                                                       'lng': 151.2048251802915},
#                                         'southwest': {'lat': -33.86986398029149,
#                                                       'lng': 151.2021272197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#               'name': 'El Loco at Slip Inn',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1331,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101329580094996437757">El '
#                                                 'Loco at Slip Inn</a>'],
#                           'photo_reference': 'ATJ83zgRfZdvFz2tBbpRrGD8cz4zlgR_vnOKbTOW57MP1ppYy93YhhiW-gzIyJoSNdtgUPRk9y4D_xE93uR-Q0m48PEYUYEHoDEGr5IPdiXKSKvm73Skkk5oL2zTkfo4EhLlwurr3niulzoTisXNonX3Mw2acssHY5mEO03c8v0X3bTRpSeJ',
#                           'width': 2000}],
#               'place_id': 'ChIJb80OxziuEmsR6n7WTeJYBE4',
#               'plus_code': {'compound_code': '46J3+H8 Sydney NSW, Australia',
#                             'global_code': '4RRH46J3+H8'},
#               'price_level': 2,
#               'rating': 3.9,
#               'reference': 'ChIJb80OxziuEmsR6n7WTeJYBE4',
#               'scope': 'GOOGLE',
#               'types': ['bar',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1836,
#               'vicinity': '111 Sussex Street, Sydney'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.86941509999999,
#                                         'lng': 151.2071166},
#                            'viewport': {'northeast': {'lat': -33.8680663197085,
#                                                       'lng': 151.2084938302915},
#                                         'southwest': {'lat': -33.8707642802915,
#                                                       'lng': 151.2057958697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'The Restaurant Pendolino',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1365,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115568244243208638832">The '
#                                                 'Restaurant Pendolino</a>'],
#                           'photo_reference': 'ATJ83zhftkjo2ASNQ9kFIciRHma8p3iVCbP-_lF_SeSOyqDiINyRgcaw5xUOm7FCQJBY72ethIJiu87vf9c9WWbHfTJeinbf1OVoDwGIzyQ62Rv2T1yceS77R3Gs3OZCQnJBP7FAayRg-b3bOQ-z8R2hOfJGKpuM6Sc2OvqtMg5LoqBi15uV',
#                           'width': 2048}],
#               'place_id': 'ChIJL1zhdD-uEmsRgDPXKOx1JyU',
#               'plus_code': {'compound_code': '46J4+6R Sydney NSW, Australia',
#                             'global_code': '4RRH46J4+6R'},
#               'price_level': 3,
#               'rating': 4.5,
#               'reference': 'ChIJL1zhdD-uEmsRgDPXKOx1JyU',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 584,
#               'vicinity': 'Shop 100/412/414 George Street, Sydney'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.8666424, 'lng': 151.2036552},
#                            'viewport': {'northeast': {'lat': -33.86534376970851,
#                                                       'lng': 151.2050183302915},
#                                         'southwest': {'lat': -33.86804173029151,
#                                                       'lng': 151.2023203697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#               'name': 'The Captains Balcony',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102407911207631727118">Sam '
#                                                 'Srinivasan</a>'],
#                           'photo_reference': 'ATJ83zhyfHupVn_Tj0Woa1OoeYIApOAqV8ctaCFd8PddUx2U-jRTZcIc3gR87XsyEsj5RamdhsSMq6QQAX350VU_zQmDdeF_UUKCLlbUNL3ZnqFQ4ImD6_J7081upB4h3bPAHiqfkMf2xMrYr-A-M1Th74FKyf_yOUBvrFQsfTTgI1QnD15w',
#                           'width': 4032}],
#               'place_id': 'ChIJ2eAQUEeuEmsRcLznK5EjcsA',
#               'plus_code': {'compound_code': '46M3+8F Sydney NSW, Australia',
#                             'global_code': '4RRH46M3+8F'},
#               'price_level': 2,
#               'rating': 4.5,
#               'reference': 'ChIJ2eAQUEeuEmsRcLznK5EjcsA',
#               'scope': 'GOOGLE',
#               'types': ['bar',
#                         'night_club',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 629,
#               'vicinity': '46 Erskine Street, Sydney'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.8674167, 'lng': 151.1936655},
#                            'viewport': {'northeast': {'lat': -33.8660488197085,
#                                                       'lng': 151.1950689302915},
#                                         'southwest': {'lat': -33.8687467802915,
#                                                       'lng': 151.1923709697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Blue Eye Dragon',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 2723,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114550096924148386356">Blue '
#                                                 'Eye Dragon</a>'],
#                           'photo_reference': 'ATJ83ziRHQQzJeYJfCOXxNpGLZdSEMRmGDAD75p7Ml6YVDoMPsM7K_sBR7VoK8sbKNvuk_uNGDqczxCl61Pqms6HvemqZPxx9kHSG1X152i5g2BrhYFPrDMggh2VLLE6W5YVAgAEAkDvHx6ikm2oDv3MASTn-RIsuYJDaiIJ4C3tXwfmNJgS',
#                           'width': 3776}],
#               'place_id': 'ChIJuZqIiTauEmsRJF_TK9Vpfmw',
#               'plus_code': {'compound_code': '45MV+2F Pyrmont NSW, Australia',
#                             'global_code': '4RRH45MV+2F'},
#               'price_level': 2,
#               'rating': 4.6,
#               'reference': 'ChIJuZqIiTauEmsRJF_TK9Vpfmw',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 385,
#               'vicinity': '37 Pyrmont Street, Pyrmont'}],
#  'status': 'OK'}
